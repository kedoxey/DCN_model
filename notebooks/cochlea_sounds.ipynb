# %%
import numpy as np
import scipy.signal as dsp
import pandas as pd
import matplotlib.pyplot as plt

# %%
import cochlea
from cnmodel.util import sound
# Out:
# ...
# --No graphics will be displayed.

# %% [markdown]
# ## CNModel

# %%
seed = 34657845

# %%
stimpar = {
    "dur": 0.3,
    "pip": 0.1,
    "start": [0.1],
    "baseline": [50, 150],
    "response": [150, 250],
}

# %%
f = 22000
db = 60

# %%
stim = sound.TonePip(
    rate=100e3,
    duration=stimpar["dur"],
    f0=f,
    dbspl=db,
    ramp_duration=2.5e-3,
    pip_duration=stimpar["pip"],
    pip_start=stimpar["start"],
)

# %%
fig, axs = plt.subplots(1,1,figsize=(5,3))
axs.plot(stim.time, stim.sound)
axs.set_xlabel('Time (s)')
# axs.set_xlim([0.145,0.15])
fig.tight_layout()

# %%
sgc_srs = [np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(2), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(2), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(0), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(1)]
sgc_cfs = [np.float64(3485.5830434325508), np.float64(4382.6394608389), np.float64(5402.023814889796), np.float64(5596.791487145855), np.float64(5700.940720014699), np.float64(5875.04539881657), np.float64(5938.094282516609), np.float64(5961.188525641507), np.float64(5993.0898361300415), np.float64(6075.065653201366), np.float64(6078.014008659484), np.float64(6122.4114378064205), np.float64(6312.449757516634), np.float64(6340.075409377921), np.float64(6818.715537862733), np.float64(7040.607903019299), np.float64(7092.036690462092), np.float64(7283.843878491542), np.float64(7326.377299522957), np.float64(7645.972440158332), np.float64(7887.127692057242), np.float64(7979.509130585905), np.float64(8041.697120332435), np.float64(8131.942420561584), np.float64(8223.200468982015), np.float64(8263.196639371932), np.float64(8686.650541638355), np.float64(8733.137166720286), np.float64(8921.5847483419), np.float64(8934.580544206827), np.float64(8964.97773445342), np.float64(9008.581776257037), np.float64(9026.082718349055), np.float64(9083.195928221936), np.float64(9315.285588094157), np.float64(9319.806489542047), np.float64(9328.854875764588), np.float64(9474.829617212863), np.float64(9516.295031513935), np.float64(9548.67132820569), np.float64(9590.459901577977), np.float64(9679.281773815273), np.float64(9693.381283442752), np.float64(9754.716874628248), np.float64(9825.971128184214), np.float64(10096.616471626197), np.float64(10126.052751763096), np.float64(10209.922428210497), np.float64(10224.794905625278), np.float64(10329.510617727703), np.float64(10430.236749789292), np.float64(10496.23484875459), np.float64(10501.328889390954), np.float64(10614.02539110249), np.float64(10639.806437271738), np.float64(10665.650104578313), np.float64(10869.39699032828), np.float64(10879.949838403507), np.float64(10932.867960637295), np.float64(11028.770030005055), np.float64(11039.477609706744), np.float64(11163.364515213547), np.float64(11174.202769611857), np.float64(11299.60158390136), np.float64(11526.638997281474), np.float64(11701.325019660653), np.float64(11752.534414384783), np.float64(11809.69663130071), np.float64(11907.51119534559), np.float64(11936.434067166248), np.float64(11965.427191493967), np.float64(12000.311914287617), np.float64(12111.452587685682), np.float64(12152.658117889245), np.float64(12182.176441849448), np.float64(12318.886909054127), np.float64(12336.831449633979), np.float64(12348.808996146769), np.float64(12366.797123303073), np.float64(12378.80376280069), np.float64(12390.82205926903), np.float64
# %%
sgc_cf_id = (np.abs(np.array(sgc_cfs)-f)).argmin()
cfs = sgc_cfs[sgc_cf_id-100:sgc_cf_id+100:10]
srs = sgc_srs[sgc_cf_id-100:sgc_cf_id+100:10]

# %%
cfs
# Out:
# [np.float64(19770.808990762824),
#  np.float64(19963.600032958988),
#  np.float64(20207.234677804612),
#  np.float64(20404.281436753954),
#  np.float64(20713.507982716965),
#  np.float64(20915.49156332777),
#  np.float64(21263.394164369758),
#  np.float64(21387.560045961578),
#  np.float64(21606.597552436557),
#  np.float64(21806.706667847113),
#  np.float64(21987.322103836945),
#  np.float64(22309.712238373282),
#  np.float64(22592.938206767845),
#  np.float64(22746.930906601785),
#  np.float64(23013.36430052036),
#  np.float64(23203.97395515748),
#  np.float64(23464.372918803845),
#  np.float64(23762.257520437954),
#  np.float64(24052.25076625355),
#  np.float64(24523.61915216359)]

# %%
spktrains = []
sgc_spks = {'spikes': [],
             'duration': [],
             'cf': [],
             'type': []}
sgc_spks_df = pd.DataFrame.from_dict(sgc_spks)

for sr, cf in zip(srs, cfs):
    
    fs = int(0.5+1./stim.dt)
    srgrp = [0,0,0]
    srgrp[2-sr] = 1

    sp = cochlea.run_zilany2014(
        stim.sound,
        fs=fs,
        anf_num=srgrp,
        cf=cf,  
        seed=seed,
        species='cat')
    
    # spktrains.append(np.array(sp.spikes.values[0]))
    sgc_spks_df = pd.concat([sgc_spks_df, sp])

# %%
sgc_spks_df
# Out:
#                                               spikes  duration            cf  \
# 0                              [0.19042000000004966]   0.30001  19770.808991
# 0  [0.028889999999998993, 0.11308999999998888, 0....   0.30001  19963.600033
# 0  [0.028869999999998994, 0.10766999999999098, 0....   0.30001  20207.234678
# 0  [0.028859999999998994, 0.10542999999999185, 0....   0.30001  20404.281437
# 0  [0.028849999999998995, 0.1037399999999925, 0.1...   0.30001  20713.507983
# 0         [0.10628999999999149, 0.17473000000003425]   0.30001  20915.491563
# 0  [0.001740000000000004, 0.01754999999999945, 0....   0.30001  21263.394164
# 0  [0.028809999999998996, 0.10250999999999298, 0....   0.30001  21387.560046
# 0  [0.001740000000000004, 0.017539999999999452, 0...   0.30001  21606.597552
# 0  [0.028789999999998997, 0.10230999999999306, 0....   0.30001  21806.706668
# 0  [0.10311999999999272, 0.12321999999998522, 0.1...   0.30001  21987.322104
# ...

# %%
fig, axs = plt.subplots(2,1,figsize=(5,7), gridspec_kw={'height_ratios': [3,1]}, sharex=True)

for i, (_, row) in enumerate(sgc_spks_df.iterrows()):
    axs[0].vlines(row.spikes, ymin=i-0.4, ymax=i+0.4, color='tab:green')

# for ax in axs:
#     ax.set_xlim([0.144,0.148])
# axs[0].set_yticks([i for i in range(len(sgc_spks_df))])
# axs[0].set_yticklabels([round(cf/1000,1) for cf in sgc_spks_df.cf.values])
axs[0].set_yticks([2, 6, 10, 14, 18])
axs[0].set_yticklabels([round(sgc_spks_df.cf.values[i]/1000,1) for i in [2, 6, 10, 14, 18]])
axs[0].set_ylabel('Characteristic Frequency (kHz)')

axs[1].plot(stim.time, stim.sound, color='k', alpha=0.7)
axs[1].set_yticks([])
axs[1].set_xticks([0, 0.05, 0.10, 0.15, 0.2, 0.25, 0.3])
axs[1].set_xticklabels([0, 50, 100, 150, 200, 250, 300])
axs[1].set_xlabel('Time (ms)')

fig.tight_layout()
fig.savefig('example_sound_inputs.pdf', dpi=300)

# %%
fig, axs = plt.subplots(2,1,figsize=(5,7), gridspec_kw={'height_ratios': [1,3]}, sharex=True)

axs[0].plot(stim.time, stim.sound)

for i, (_, row) in enumerate(sgc_spks_df.iterrows()):
    axs[1].vlines(row.spikes, ymin=i-0.4, ymax=i+0.4)

# for ax in axs:
axs[1].set_yticks([i for i in range(len(sgc_spks_df))])
axs[1].set_yticklabels([round(cf/1000,1) for cf in sgc_spks_df.cf.values])
axs[1].set_ylabel('Characteristic Frequency (kHz)')

axs[1].set_xlim([0.175,0.185])
axs[1].set_xlabel('Time (s)')

fig.tight_layout()

# %% [markdown]
# ## All ANF

# %%
# 100,000 Hz -> dt = 0.01 ms
fs = 100e3    # Hz
dt = 1/fs     # seconds
duration = 0.1  # seconds

t = np.linspace(0, duration, int(duration*fs))

# %%
cf_all = 1000     # Hz
s_all = np.sin(2*np.pi*t*cf_all)
plt.plot(t,s_all)

# %%
anf_trains_all = cochlea.run_zilany2014(
    s_all, 
    fs,
    anf_num=(1,0,0),
    cf=(1.25e3,20e3,200),
    seed=0,
    species='cat'
)

all_cfs = np.array(anf_trains_all.cf.values)

anf_trains_all
# Out:
#                                                 spikes  duration  \
# 0    [0.002250000000000005, 0.004649999999999977, 0...       0.1
# 1    [0.002290000000000005, 0.00456999999999998, 0....       0.1
# 2    [0.002170000000000005, 0.006349999999999908, 0...       0.1
# 3    [0.0023300000000000052, 0.006669999999999895, ...       0.1
# 4    [0.002200000000000005, 0.004609999999999979, 0...       0.1
# ..                                                 ...       ...
# 195  [0.0011300000000000023, 0.003920000000000007, ...       0.1
# 196  [0.0004800000000000006, 0.002970000000000005, ...       0.1
# 197  [0.0011600000000000024, 0.0049099999999999665,...       0.1
# 198  [0.0009500000000000018, 0.004929999999999966, ...       0.1
# 199  [0.001010000000000002, 0.00580999999999993, 0....       0.1
#
#                cf type
# 0     1250.000000  hsr
# 1     1270.698707  hsr
# 2     1291.662733  hsr
# 3     1312.895478  hsr
# 4     1334.400387  hsr
# ..            ...  ...
# ...

# %%
fig, axs = plt.subplots(1,1,figsize=(5,5))

for i, row in anf_trains_all.iterrows():

    axs.vlines(row.spikes, ymin=i-0.25, ymax=i+0.25)

yticks = [i-1 if i>0 else i for i in list(np.arange(0,220,20))]
ytick_labels = np.round(all_cfs[yticks])

axs.set_yticks(yticks)
axs.set_yticklabels(ytick_labels)
axs.set_ylabel('Center Frequency (Hz)')
axs.set_xlabel('Time (s)')
axs.set_title('All Frequencies')
fig.tight_layout()

# %% [markdown]
# ## Middle ANF

# %%
cf_med = 4108     # Hz
s_med = np.sin(2*np.pi*t*cf_med)
plt.plot(t,s_med)

# %%
anf_trains_med = cochlea.run_zilany2014(
    s_med, 
    fs,
    anf_num=(0,0,1),
    cf=(1.25e3,20e3,200),
    seed=0,
    species='cat'
)

med_cfs = np.array(anf_trains_med.cf.values)

anf_trains_med
# Out:
#                       spikes  duration            cf type
# 0                         []       0.1   1250.000000  lsr
# 1                         []       0.1   1270.698707  lsr
# 2    [0.0031200000000000073]       0.1   1291.662733  lsr
# 3                         []       0.1   1312.895478  lsr
# 4                         []       0.1   1334.400387  lsr
# ..                       ...       ...           ...  ...
# 195                       []       0.1  18988.467161  lsr
# 196                       []       0.1  19236.539743  lsr
# 197                       []       0.1  19487.792150  lsr
# 198                       []       0.1  19742.265142  lsr
# 199                       []       0.1  20000.000000  lsr
#
# [200 rows x 4 columns]

# %%
fig, axs = plt.subplots(1,1,figsize=(5,5))

for i, row in anf_trains_med.iterrows():

    axs.vlines(row.spikes, ymin=i-0.25, ymax=i+0.25)

yticks = [i-1 if i>0 else i for i in list(np.arange(0,220,20))]
ytick_labels = np.round(med_cfs[yticks])

axs.set_yticks(yticks)
axs.set_yticklabels(ytick_labels)
axs.set_ylabel('Center Frequency (Hz)')
axs.set_xlabel('Time (s)')
axs.set_title('Middle Frequencies')
fig.tight_layout()

# %% [markdown]
# ## High Frequencies

# %%
cf_high = 15420     # Hz
s_high = np.sin(2*np.pi*t*cf_high)
plt.plot(t,s_high)

# %%
anf_trains_high = cochlea.run_zilany2014(
    s_high, 
    fs,
    anf_num=(0,0,1),
    cf=(1.25e3,20e3,200),
    seed=0,
    species='cat'
)

high_cfs = np.array(anf_trains_high.cf.values)

anf_trains_high
# Out:
#                                                 spikes  duration  \
# 0                                                   []       0.1
# 1                                                   []       0.1
# 2                               [0.004599999999999981]       0.1
# 3                                                   []       0.1
# 4                                                   []       0.1
# ..                                                 ...       ...
# 195  [0.008189999999999835, 0.01675999999999952, 0....       0.1
# 196  [0.0011200000000000023, 0.01315999999999963, 0...       0.1
# 197  [0.015469999999999538, 0.03299999999999946, 0....       0.1
# 198  [0.001410000000000003, 0.022929999999999232, 0...       0.1
# 199  [0.0028600000000000066, 0.02961999999999896, 0...       0.1
#
#                cf type
# 0     1250.000000  lsr
# 1     1270.698707  lsr
# 2     1291.662733  lsr
# 3     1312.895478  lsr
# 4     1334.400387  lsr
# ..            ...  ...
# ...

# %%
fig, axs = plt.subplots(1,1,figsize=(5,5))

for i, row in anf_trains_high.iterrows():

    axs.vlines(row.spikes, ymin=i-0.25, ymax=i+0.25)

yticks = [i-1 if i>0 else i for i in list(np.arange(0,220,20))]
ytick_labels = np.round(high_cfs[yticks])

axs.set_yticks(yticks)
axs.set_yticklabels(ytick_labels)
axs.set_ylabel('Center Frequency (Hz)')
axs.set_xlabel('Time (s)')
axs.set_title('High Frequencies')
fig.tight_layout()

# %% [markdown]
# ## Sandbox

# %%
fig, axs = plt.subplots(1,1,figsize=(5,5))

for i, row in anf_trains_med.iterrows():

    axs.vlines(row.spikes, ymin=i-0.25, ymax=i+0.25)

yticks = [i-1 if i>0 else i for i in list(np.arange(0,220,20))]
ytick_labels = np.round(med_cfs[yticks])

axs.set_yticks(yticks)
axs.set_yticklabels(ytick_labels)
axs.set_ylabel('Center Frequency (Hz)')
axs.set_xlabel('Time (s)')
axs.set_title('LSR Middle Frequencies')
fig.tight_layout()

# %%
anf_trains = cochlea.run_zilany2014(
    s, 
    fs,
    anf_num=(0,1,0),
    cf=(1.25e3,20e3,200),
    seed=0,
    species='cat'
)

fig, axs = plt.subplots(1,1,figsize=(5,5))

for i, row in anf_trains.iterrows():

    axs.vlines(row.spikes, ymin=i-0.25, ymax=i+0.25)

axs.set_yticks(list(range(200))[0::9])
axs.set_yticklabels([round(cen_freq) for cen_freq in anf_trains.cf.values][0::9])
axs.set_ylabel('Center Frequency (Hz)')
axs.set_xlabel('Time (s)')
axs.set_title('MSR')
fig.tight_layout()

# %%
anf_trains = cochlea.run_zilany2014(
    s, 
    fs,
    anf_num=(1,0,0),
    cf=(1.25e3,20e3,200),
    seed=0,
    species='cat'
)

fig, axs = plt.subplots(1,1,figsize=(5,5))

for i, row in anf_trains.iterrows():

    axs.vlines(row.spikes, ymin=i-0.25, ymax=i+0.25)

axs.set_yticks(list(range(200))[0::9])
axs.set_yticklabels([round(cen_freq) for cen_freq in anf_trains.cf.values][0::9])
axs.set_ylabel('Center Frequency (Hz)')
axs.set_xlabel('Time (s)')
axs.set_title('HSR')
fig.tight_layout()

# %%
num_cfs = 100

anf_trains = cochlea.run_zilany2014(
    s, 
    fs,
    anf_num=(0,1,1),
    cf=(1.25e3,20e3,200),
    seed=0,
    species='cat'
)

anf_trains

fig, axs = plt.subplots(1,1,figsize=(5,5))

for i, row in anf_trains.iterrows():

    row_cf = row.cf
    axs.vlines(row.spikes, ymin=row_cf-0.25, ymax=row_cf+0.25)

# axs.set_yticks(list(range(num_cfs))[0::9])
# axs.set_yticklabels([round(cen_freq) for cen_freq in np.unique(anf_trains.cf.values)][0::9])
axs.set_ylabel('Center Frequency (Hz)')
axs.set_xlabel('Time (s)')
axs.set_title('MSR + LSR')
fig.tight_layout()

# %%
def plot_raster(spike_trains, ax=None, style='k.', **kwargs):
    """Plot raster plot."""

    trains = spike_trains['spikes']
    duration = np.max( spike_trains['duration'] )

    # Compute trial number
    L = [ len(train) for train in trains ]
    r = np.arange(len(trains))
    n = np.repeat(r, L)

    # Spike timings
    s = np.concatenate(tuple(trains))


    if ax is None:
        import matplotlib.pyplot as plt
        ax = plt.gca()

    ax.plot(s, n, style, **kwargs)
    ax.set_xlabel("Time (s)")
    ax.set_xlim( (0, duration) )
    ax.set_ylabel("Train Number")
    ax.set_ylim( (-0.5, len(trains)-0.5) )


    return ax

# %%
num_cfs = 100

anf_trains = cochlea.run_zilany2014(
    s, 
    fs,
    anf_num=(0,1,1),
    cf=(1.25e3,20e3,200),
    seed=0,
    species='cat'
)

anf_trains

fig, axs = plt.subplots(1,1,figsize=(5,5))

plot_raster(anf_trains, ax=axs)
fig.tight_layout()

# for i, row in anf_trains.iterrows():

#     row_cf = row.cf
#     axs.vlines(row.spikes, ymin=row_cf-0.25, ymax=row_cf+0.25)

# # axs.set_yticks(list(range(num_cfs))[0::9])
# # axs.set_yticklabels([round(cen_freq) for cen_freq in np.unique(anf_trains.cf.values)][0::9])
# axs.set_ylabel('Center Frequency (Hz)')
# axs.set_xlabel('Time (s)')
# axs.set_title('MSR + LSR')
# fig.tight_layout()
